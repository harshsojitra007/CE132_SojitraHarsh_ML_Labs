# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsojitra007/CE132_ML_Labs/blob/main/ML_Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_breast_cancer()
features = data.data
labels = data.target

model = svm.SVC(kernel='linear')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted)))
print('Recall {}'.format(recall_score(testL, predicted)))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9649122807017544
# Precision 0.9411764705882353
# Recall 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        50
#            1       0.94      1.00      0.97        64
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_breast_cancer()
features = data.data
labels = data.target

model = svm.SVC(kernel='poly')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted)))
print('Recall {}'.format(recall_score(testL, predicted)))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.868421052631579
# Precision 0.8266666666666667
# Recall 0.96875
#               precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83        50
#            1       0.83      0.97      0.89        64
#
#     accuracy                           0.87       114
#    macro avg       0.89      0.85      0.86       114
# weighted avg       0.88      0.87      0.87       114

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_breast_cancer()
features = data.data
labels = data.target

model = svm.SVC(kernel='rbf')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted)))
print('Recall {}'.format(recall_score(testL, predicted)))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.8771929824561403
# Precision 0.8378378378378378
# Recall 0.96875
#               precision    recall  f1-score   support
#
#            0       0.95      0.76      0.84        50
#            1       0.84      0.97      0.90        64
#
#     accuracy                           0.88       114
#    macro avg       0.89      0.86      0.87       114
# weighted avg       0.89      0.88      0.87       114

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

model = svm.SVC(kernel='linear')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9888888888888889
# Precision 0.9891093474426808
# Recall 0.9888888888888889
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       0.98      1.00      0.99        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        28
#            4       1.00      1.00      1.00        27
#            5       1.00      0.97      0.99        38
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        46
#            8       0.92      0.96      0.94        23
#            9       0.97      0.95      0.96        37
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

model = svm.SVC(kernel='poly')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9888888888888889
# Precision 0.9893553791887126
# Recall 0.9888888888888889
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        28
#            4       0.96      1.00      0.98        27
#            5       1.00      0.95      0.97        38
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        46
#            8       0.92      1.00      0.96        23
#            9       0.97      0.95      0.96        37
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

# decreasing value of C tends to reduce accuracy of the model
model = svm.SVC(kernel='poly', C=1000)

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9888888888888889
# Precision 0.9893553791887126
# Recall 0.9888888888888889
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        28
#            4       0.96      1.00      0.98        27
#            5       1.00      0.95      0.97        38
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        46
#            8       0.92      1.00      0.96        23
#            9       0.97      0.95      0.96        37
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

model = svm.SVC(kernel='rbf')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9916666666666667
# Precision 0.992033950617284
# Recall 0.9916666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        28
#            4       1.00      0.96      0.98        27
#            5       1.00      1.00      1.00        38
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        46
#            8       0.92      1.00      0.96        23
#            9       0.97      0.95      0.96        37
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

# decreasing value of C tends to reduce accuracy of the model
model = svm.SVC(kernel='rbf', C=100000)

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9916666666666667
# Precision 0.992033950617284
# Recall 0.9916666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        28
#            4       1.00      1.00      1.00        27
#            5       1.00      0.97      0.99        38
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        46
#            8       0.92      1.00      0.96        23
#            9       0.97      0.95      0.96        37
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360
