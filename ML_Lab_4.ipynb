# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsojitra007/CE132_ML_Labs/blob/main/ML_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practice

# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
import torch.nn.functional as F

inputs = np.array([[73, 67, 43],
          [91, 88, 64],
          [87, 134, 58],
          [102, 43, 37],
          [69, 96, 70]], dtype='float32')

targets = np.array([[56],
            [81],
            [119],
            [22],
            [103]], dtype='float32')

weight = np.array([12, 3, 9])
bias = [4]

inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)

inputs = torch.tensor(inputs)
targets = torch.tensor(targets)

dataset = TensorDataset(inputs, targets)
loader = DataLoader(dataset)


def calculate(instanceCount, model, loss_fn, optimizer):
  for i in range(instanceCount):
    for inp, targ in dataset:
      output = model(inp)
      loss = loss_fn(output, targ)
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()
      print(loss);
      ret

# print(dataset, '\n', loader)
model = torch.nn.Linear(3, 1)
optimizer = optim.SGD(model.parameters(), lr=0.0000001)
loss_fn = F.mse_loss

print(model.weight)
print(model.bias)

for i in range(1000):
  for inputs, targets in dataset:
    def closure():
      optimizer.zero_grad()
      output = model(inputs)
      loss = loss_fn(output, targets)
      # print(loss)
      loss.backward()
      return loss
    optimizer.step(closure)

print(model(torch.tensor([70., 34., 45.])))
# Out:
# <ipython-input-32-776ca5287110>:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inputs = torch.tensor(inputs)
# <ipython-input-32-776ca5287110>:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   targets = torch.tensor(targets)
# Parameter containing:
# tensor([[ 0.2166, -0.0459,  0.1336]], requires_grad=True)
# Parameter containing:
# tensor([-0.0633], requires_grad=True)
# tensor([43.4996], grad_fn=<AddBackward0>)

# %%
import matplotlib.pyplot as plt

x = [50, 100, 500, 700, 800, 900, 1000]
y = [648.4023, 391.0272, 133.6041, 244.1809, 324.2377, 273.7362, 100.2437]

plt.plot(x, y)
plt.xlabel('No. of Epochs')
plt.ylabel('Loss')
plt.title('Epochs vs Loss')
  
# function to show the plot
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
